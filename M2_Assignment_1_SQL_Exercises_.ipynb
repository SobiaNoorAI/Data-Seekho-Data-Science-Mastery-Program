# %% [markdown]
# <a href="https://colab.research.google.com/github/SobiaNoorAI/Data-Seekho-Data-Science-Mastery-Program/blob/main/M2_Assignment_1_SQL_Exercises_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  **Assignment no 1**
# Perform all SQL Exercises
# *   SELECT
# *   FROM
# *   WHERE
# *   AND
# *   OR
# *   NOT
# *   NULL
# *   JOIN
# *   ORDER BY
# *   GROUP BY
# *   HAVING
# *   LIMIT
# *   INSERT
# *   UPDATE
# *   DELETE
# *   FUNCTION
# *   LIKE WILDCARDS
# *   IN
# *   BETWEEN
# *   ALIAS
# *   DATABASE

# %% [markdown]
# [SQL Exercise on w3school](https://www.w3schools.com/sql/exercise.asp)

# %% [markdown]
# ![sql statements.PNG](data:image/png;base64,...)
