# %% [markdown]
# <a href="https://colab.research.google.com/github/SobiaNoorAI/Data-Seekho-Data-Science-Mastery-Program/blob/main/MODULE%203%3A%20DATA%20VISUALIZATION%20AND%20ANALYSIS/Assignment%201%3A%20Exploring%20Visualizations%20with%20Power%20BI%2C%20Matplotlib%2C%20and%20Seaborn/Python_Visualization_(Matplotlib_Seaborn).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Visualization (Matplotlib/Seaborn)

# %% [markdown]
# # Import Dataset

# %%
  #Import Libraries
  import sqlite3
  import pandas as pd

  #connect database
  conn = sqlite3.connect('database.db')
  cursor = conn.cursor()

  # Load CSV datasets
  data = pd.read_csv('https://raw.githubusercontent.com/SobiaNoorAI/Data-Seekho-Data-Science-Mastery-Program/main/MODULE%203%3A%20DATA%20VISUALIZATION%20AND%20ANALYSIS/Assignment%201%3A%20Exploring%20Visualizations%20with%20Power%20BI%2C%20Matplotlib%2C%20and%20Seaborn/Data/data.csv')

  # Write data into database tables
  #data.to_sql('sales_data', conn, if_exists='replace', index=False)
  print("Database created and populated successfully.")
# Out:
# Database created and populated successfully.

# %%
#data.head()
# Out:
#    OrderID  Revenue  Discounts  Taxes  TransactionID   OrderDate  CustomerID  \
# 0     1000     1755         30     65           1000  2023-02-11           6
# 1     1001     1727         76    101           1001  2024-06-09          22
# 2     1002     1834         25     23           1002  2022-12-11          31
# 3     1003      896         94    123           1003  2022-12-18          23
# 4     1004     1868         51     63           1004  2024-04-11          42
#
#    ProductID  Quantity  TotalAmount  Month ProductName         Category  \
# 0        212         4          426      2        Mind      Accessories
# 1        226         8          184      6      Suffer      Accessories
# 2        231         5          880     12        Role  Home Appliances
# 3        227        10          928     12       North  Home Appliances
# 4        215         7          517      4        Both      Accessories
#
#    Price          Name   Region    Segment
# 0     67  Lauren Walls     West  Wholesale
# 1    179     Lori Cole  Central  Wholesale
# 2     82   Sherri Knox    South  Wholesale
# 3    221    Randy Duke    North     Retail
# 4    334   Zachary Ray  Central  Corporate

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1) Line Plot

# %%
plt.figure(figsize=(10,6))
plt.plot(data['Quantity'], data['Month'], color='blue')
plt.xlabel('Month')
plt.ylabel('Price')
plt.title("Product Price Per Month")
plt.show()

# %%
# Line Chart: Revenue Over Months
plt.figure(figsize=(10, 6))
monthly_revenue=data.groupby('Month')['Revenue'].sum()
monthly_revenue.plot(kind='line', marker='o', color='blue')
plt.title('Revenue Over Months', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Revenue', fontsize=12)
plt.grid()
plt.show()

# %% [markdown]
# ## 2) Bar Plot

# %%
# Bar Chart: Revenue by Region
plt.figure(figsize=(10, 6))
regional_revenue=data.groupby('Region')['Revenue'].sum()
regional_revenue.plot(kind='bar', color='orange')
plt.title('Revenue by Region', fontsize=16)
plt.xlabel('Region', fontsize=12)
plt.ylabel('Revenue', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(data['Month'], data['TotalAmount'], color='green')
plt.xlabel('Month')
plt.ylabel('Total Amount')
plt.title('Total Amount Sold Per Month')
plt.show()

# %% [markdown]
# ## 3) Histogram

# %%
# Histogram: Revenue Distribution
plt.figure(figsize=(10, 6))
plt.hist(data['Revenue'], bins=17, color='purple', alpha=0.7)
plt.title('Revenue Distribution', fontsize=16)
plt.xlabel('Revenue', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(data['Price'], bins=17, color='skyblue', edgecolor='black')
plt.title('Distribution of Product Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(True)

# %% [markdown]
# ## 4) Scatter Plot

# %%
plt.figure(figsize=(10,5))
plt.scatter(data['Quantity'], data['Revenue'], color='orange', marker='o')
plt.xlabel('Discounts')
plt.ylabel('Revenue')
plt.title('Discount vs Revenue')
# Out:
# Text(0.5, 1.0, 'Discount vs Revenue')

# %%
# Scatter Plot: Revenue vs Quantity
plt.figure(figsize=(10, 6))
plt.scatter(data['Quantity'], data['Revenue'], alpha=0.7, color='green')
plt.title('Revenue vs Quantity', fontsize=16)
plt.xlabel('Quantity', fontsize=12)
plt.ylabel('Revenue', fontsize=12)
plt.grid()
plt.show()

# %% [markdown]
# ## 5) Pie Chart

# %%
# Pie Chart: Revenue by Segment
plt.figure(figsize=(5, 5))
plt.pie(regional_revenue, labels=regional_revenue.index, autopct='%1.1f%%', startangle=140)
plt.title('Revenue Share by Segment', fontsize=16)
plt.show()

# %%
#pie chat
plt.pie(data['Revenue'], labels=data['Region'], autopct='%1.1f%%', startangle=90)
plt.title('Revenue Distribution by Region')
plt.show()

# %% [markdown]
# ## 6) Box Plot

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(data['Revenue'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.title('Revenue Distribution', fontsize=16)
plt.xlabel('Revenue', fontsize=12)
plt.grid()
plt.show()

# %% [markdown]
# ## 7) Area Plot

# %%
# Area Chart: Cumulative Revenue Over Months
cumulative_revenue = data.groupby('Month')['Revenue'].sum().cumsum()
plt.figure(figsize=(10, 6))
plt.fill_between(cumulative_revenue.index, cumulative_revenue, color='skyblue', alpha=0.4)
plt.title('Cumulative Revenue Over Months', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Cumulative Revenue', fontsize=12)
plt.grid()
plt.show()

# %% [markdown]
# # Seaborn

# %%
#import library
import seaborn as sns

# %% [markdown]
# ## 1) Line Plot

# %%
# Line Plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=data.groupby('Region')['Revenue'].sum().reset_index(), x='Month', y='Revenue', marker='o')
plt.title('Revenue Trend Over Months')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-c13b6f1f5c7a> in <cell line: 3>()
#       1 # 1. Line Plot
#       2 plt.figure(figsize=(10, 6))
# ----> 3 sns.lineplot(data=data.groupby('Region')['Revenue'].sum().reset_index(), x='Month', y='Revenue', marker='o')
#       4 plt.title('Revenue Trend Over Months')
#       5 plt.xlabel('Month')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     483     errorbar = _deprecate_ci(errorbar, ci)
#     484
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     214         )
#     215
# --> 216         super().__init__(data=data, variables=variables)
#     217
#     218         self.estimator = estimator
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py in __init__(self, data, variables)
#     632         # information for numeric axes would be information about log scales.
#     633         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634         self.assign_variables(data, variables)
#     635
#     636         # TODO Lots of tests assume that these are called to initialize the
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py in assign_variables(self, data, variables)
#     677             # to centralize / standardize data consumption logic.
#     678             self.input_format = "long"
# --> 679             plot_data = PlotData(data, variables)
#     680             frame = plot_data.frame
#     681             names = plot_data.names
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_core/data.py in __init__(self, data, variables)
#      56
#      57         data = handle_data_source(data)
# ---> 58         frame, names, ids = self._assign_variables(data, variables)
#      59
#      60         self.frame = frame
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_core/data.py in _assign_variables(self, data, variables)
#     230                 else:
#     231                     err += "An entry with this name does not appear in `data`."
# --> 232                 raise ValueError(err)
#     233
#     234             else:
#
# ValueError: Could not interpret value `Month` for `x`. An entry with this name does not appear in `data`.

# %% [markdown]
# ## 2) Bar Plot

# %%
# Bar Chart
plt.figure(figsize=(10, 6))
sns.barplot(data=data.groupby('Region')['Revenue'].sum().reset_index(), x='Region', y='Revenue' ,hue='Revenue')
plt.title('Revenue by Region')
plt.xlabel('Region')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# ## 3) Histogram

# %%
# Histogram
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='Revenue', bins=20, kde=True, color='green')
plt.title('Revenue Distribution')
plt.xlabel('Revenue')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 4) Scatter Plot

# %%
# Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Quantity', y='Revenue', hue='Region', palette='Set1')
plt.title('Quantity vs. Revenue')
plt.xlabel('Quantity')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# ## 5) Pie Plot

# %%
# Pie Chart
regional_revenue = data.groupby('Region')['Revenue'].sum()
plt.figure(figsize=(5, 5))
plt.pie(regional_revenue, labels=regional_revenue.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Revenue Share by Region')
plt.show()

# %% [markdown]
# ## 6) Box Plot

# %%
# Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Region', y='Revenue', palette='Set2')
plt.title('Revenue Distribution by Region')
plt.xlabel('Region')
plt.ylabel('Revenue')
plt.show()
# Out:
# <ipython-input-43-e115fdc07849>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='Region', y='Revenue', palette='Set2')

# %% [markdown]
# ## 7) Area Plot

# %%
# Area Chart
cumulative_revenue = data.groupby('Month')['Revenue'].sum().cumsum().reset_index()
plt.figure(figsize=(10, 6))
plt.fill_between(cumulative_revenue['Month'], cumulative_revenue['Revenue'], color="skyblue", alpha=0.4)
plt.plot(cumulative_revenue['Month'], cumulative_revenue['Revenue'], color="Slateblue", alpha=0.7, linewidth=2)
plt.title('Revenue Area Chart Over Months')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.grid(True)
plt.show()
